# %%
import pandas as pd
date='2022-04-25'
df_output=pd.read_excel(r"\\DESKTOP-KJM0HRO\Shared_Folder\Automation\Step Allocation Audt" + "\\" + date + "\\" + "reupload.xlsx")

# %%
len(df_output)
# Out:
# 3

# %%
## SSS full code :- working fully final version

from selenium.webdriver.support.ui import WebDriverWait
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import pyautogui
import time


spcentral_username = "spn-spc-admin@amazon.com"
spcentral_password = "spn@123"
df = pd.DataFrame()
df_fail = pd.DataFrame()


#a=9
date='2022-04-25'
for i in range (0,len(df_output)):
    try:

        driver_path = r"\\DESKTOP-KJM0HRO\Shared_Folder\Automation\Step Allocation Audt\chromedriver_win32\chromedriver.exe"
        path1 = r'https://spcentral.amazon.com'
        options = webdriver.ChromeOptions()
        options.add_argument("--start-maximized")
        options.add_argument("--disable-notifications")
        driver = webdriver.Chrome(executable_path=driver_path, options=options)
        driver.get(path1)

    # Login
        email = WebDriverWait(driver, 10).until(
            EC.visibility_of_element_located((By.XPATH, '(//*[@id="ap_email"])')))
        email.send_keys(spcentral_username)

        password = WebDriverWait(driver, 10).until(
            EC.presence_of_element_located((By.XPATH, '(//*[@id="ap_password"])')))
        password.send_keys(spcentral_password)

        login = WebDriverWait(driver, 10).until(
           EC.presence_of_element_located((By.XPATH, '(//*[@id="signInSubmit"])'))).click()

        time.sleep(5)


    # add request



        add_request_button = WebDriverWait(driver, 10).until(
            EC.presence_of_element_located((By.XPATH, '(//*[@id="a-autoid-1-announce"])'))).click()

        ## seller_email

        seller_email= WebDriverWait(driver, 10).until(
        EC.visibility_of_element_located((By.XPATH, '(//*[@id="sellerEmail"])')))
        seller_email.send_keys(df_output['Email'].values[i])
        time.sleep(2)


        ## fill the provider_id column

        provider_id= WebDriverWait(driver, 10).until(
        EC.visibility_of_element_located((By.XPATH, '(//*[@id="providerIdentifier"])')))
        provider_id.send_keys(df_output['Provider_Id'].values[i])
        time.sleep(2)

        ## fill the seller_name column

        seller_name= WebDriverWait(driver, 10).until(
        EC.visibility_of_element_located((By.XPATH, '//*[@id="sellerName"]')))
        seller_name.send_keys(df_output['STEP_SPN_Name'].values[i])
        time.sleep(2)

        ## fill the seller_number column

        seller_name= WebDriverWait(driver, 10).until(
        EC.visibility_of_element_located((By.XPATH, '//*[@id="sellerPhone"]')))
        seller_name.send_keys(str(df_output['STEP_SPN_Contact'].values[i]))
        time.sleep(2)

        ## service form filling


        ## filling  the service form-for loop

        WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, '//*[@id="service"]/span/span'))).click()



        if df_output['Select one of the SPN services'].values[i]=='Account Management':

           #driver.find_element_by_id('service-dropdown_0').click()
            #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Account Management')))
            driver.find_element_by_link_text("Account Management").click()
        elif df_output['Select one of the SPN services'].values[i]=='Accounting':

           #driver.find_element_by_id('service-dropdown_0').click()
            #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Account Management')))
            driver.find_element_by_link_text("Accounting").click()    

        elif df_output['Select one of the SPN services'].values[i]=='Advertising Optimization':

           #driver.find_element_by_id('service-dropdown_1').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Advertisement Optimization')))
            driver.find_element_by_link_text("Advertising Optimization").click()

        elif df_output['Select one of the SPN services'].values[i]=='Cataloging':

           #driver.find_element_by_id('service-dropdown_2').click() 
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Cataloging')))
            driver.find_element_by_link_text("Cataloguing").click()


        elif df_output['Select one of the SPN services'].values[i]=='Compliance':
           #driver.find_element_by_id('service-dropdown_2').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Compliance')))
            driver.find_element_by_link_text("Compliance").click()


        elif df_output['Select one of the SPN services'].values[i]=='Enhanced Brand Content':
           #driver.find_element_by_id('service-dropdown_3').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Enhanced Brand Content')))
            driver.find_element_by_link_text("Enhanced Brand Content").click()
            
        elif df_output['Select one of the SPN services'].values[i]=='Brand Videos':
           #driver.find_element_by_id('service-dropdown_3').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Enhanced Brand Content')))
            driver.find_element_by_link_text("Enhanced Brand Content").click()    
            


        elif df_output['Select one of the SPN services'].values[i]=='Imaging':
           #driver.find_element_by_id('service-dropdown_4').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Imaging'))) 
            driver.find_element_by_link_text("Imaging").click()


        elif df_output['Select one of the SPN services'].values[i]=='Training':
           #driver.find_element_by_id('service-dropdown_6').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Training')))
            driver.find_element_by_link_text("Training").click()



        time.sleep(2)


        ## filling  the service type-for loop


        WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, '//*[@id="serviceTypeRequested"]/span/span/span'))).click()



        if df_output['Select one of the SPN services'].values[i]=='Account Management':


           #driver.find_element_by_id('serviceTypeRequested-dropdown_6').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Unknown')))
            driver.find_element_by_link_text("Unknown").click()
            
        elif df_output['Select one of the SPN services'].values[i]=='Accounting':


           #driver.find_element_by_id('serviceTypeRequested-dropdown_6').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Unknown')))
            driver.find_element_by_link_text("Unknown").click()    

        elif df_output['Select one of the SPN services'].values[i]=='Advertising Optimization':

           #driver.find_element_by_id('serviceTypeRequested-dropdown_4').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Unknown')))
            driver.find_element_by_link_text("Unknown").click()

        elif df_output['Select one of the SPN services'].values[i]=='Cataloging':

           #driver.find_element_by_id('serviceTypeRequested-dropdown_2').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Unknown')))
            driver.find_element_by_link_text("Unknown").click()

        elif df_output['Select one of the SPN services'].values[i]=='Compliance':

           #driver.find_element_by_id('serviceTypeRequested-dropdown_4').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Unknown')))
            driver.find_element_by_link_text("Unknown").click()

        elif df_output['Select one of the SPN services'].values[i]=='Enhanced Brand Content':

           #driver.find_element_by_id('serviceTypeRequested-dropdown_1').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Unknown')))
            driver.find_element_by_link_text("Unknown").click()
            
            
        elif df_output['Select one of the SPN services'].values[i]=='Brand Videos':

           #driver.find_element_by_id('serviceTypeRequested-dropdown_1').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Unknown')))
            driver.find_element_by_link_text("EBC Product Videos").click()    
            

        elif df_output['Select one of the SPN services'].values[i]=='Imaging':

           #driver.find_element_by_id('serviceTypeRequested-dropdown_4').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Unknown')))
            driver.find_element_by_link_text("Unknown").click()



        elif df_output['Select one of the SPN services'].values[i]=='Training':

           #driver.find_element_by_id('serviceTypeRequested-dropdown_2').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Unknown')))
            driver.find_element_by_link_text("Unknown").click()


        time.sleep(2)

        ## Seller sell in country

        driver.find_element_by_xpath('//*[@id="sellerSellInCountry"]/span/span').click()
        #driver.find_element_by_id('sellerSellInCountry-dropdown_0').click()
        #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'India')))
        driver.find_element_by_link_text("India").click()

        ## filling  the seller locaton country form

        time.sleep(2)


        driver.find_element_by_xpath('//*[@id="sellerLocation"]/span/span/span').click()
        #driver.find_element_by_id('sellerLocation-dropdown_1').click()
        #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'India')))
        driver.find_element_by_link_text("India").click()

        submit_button = WebDriverWait(driver, 10).until(
           EC.presence_of_element_located((By.XPATH, '//*[@id="offline-form-container"]/form/div[5]/div/span/span/input'))).click()
        driver.refresh()

        time.sleep(5)
        driver.find_element_by_xpath('//*[@id="nav-search-text"]').clear()
        time.sleep(2)


    ## search user and click on page



        filter_box=driver.find_element_by_xpath('//*[@id="nav-search-text"]')
        filter_box.send_keys(df_output['Email'].values[i])


     #search

        driver.find_element_by_xpath('//*[@id="nav-search-button"]/span/input').click()
        time.sleep(5)

    ## filter

        driver.find_element_by_xpath('//*[@id="filter-dropdown-btn"]').click()
        time.sleep(5)


    ##  expland service filter type

        driver.find_element_by_xpath('//*[@id="filter-section-expand-serviceType"]').click()
        time.sleep(5)

    ##  select the service filter
        if df_output['Select one of the SPN services'].values[i]=='Account Management':


           #driver.find_element_by_id('serviceTypeRequested-dropdown_6').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Unknown')))
            driver.find_element_by_xpath('//*[@id="filter-options-serviceType"]/div[18]/div[2]/div/label/i').click()
            
        elif df_output['Select one of the SPN services'].values[i]=='Accounting':


           #driver.find_element_by_id('serviceTypeRequested-dropdown_6').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Unknown')))
            driver.find_element_by_xpath('//*[@id="filter-options-serviceType"]/div[5]/div[2]/div/label/i').click()    
            

        elif df_output['Select one of the SPN services'].values[i]=='Advertising Optimization':

           #driver.find_element_by_id('serviceTypeRequested-dropdown_4').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Unknown')))
            driver.find_element_by_xpath('//*[@id="filter-options-serviceType"]/div[1]/div[2]/div/label/i').click()

        elif df_output['Select one of the SPN services'].values[i]=='Cataloging':

           #driver.find_element_by_id('serviceTypeRequested-dropdown_2').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Unknown')))
            driver.find_element_by_xpath('//*[@id="filter-options-serviceType"]/div[16]/div[2]/div/label/i').click()

        elif df_output['Select one of the SPN services'].values[i]=='Compliance':

           #driver.find_element_by_id('serviceTypeRequested-dropdown_4').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Unknown')))
            driver.find_element_by_xpath('//*[@id="filter-options-serviceType"]/div[4]/div[2]/div/label/i').click()

        elif df_output['Select one of the SPN services'].values[i]=='Enhanced Brand Content':

           #driver.find_element_by_id('serviceTypeRequested-dropdown_1').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Unknown')))
            driver.find_element_by_xpath('//*[@id="filter-options-serviceType"]/div[9]/div[2]/div/label/i').click()

        elif df_output['Select one of the SPN services'].values[i]=='Imaging':

           #driver.find_element_by_id('serviceTypeRequested-dropdown_4').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Unknown')))
            driver.find_element_by_xpath('//*[@id="filter-options-serviceType"]/div[17]/div[2]/div/label/i').click()



        elif df_output['Select one of the SPN services'].values[i]=='Training':

           #driver.find_element_by_id('serviceTypeRequested-dropdown_4').click()
           #WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.LINK_TEXT, 'Unknown')))
            driver.find_element_by_xpath('//*[@id="filter-options-serviceType"]/div[10]/div[2]/div/label/i').click()
    ## collpase service



        driver.find_element_by_xpath('//*[@id="filter-section-collapse-serviceType"]').click()
        time.sleep(5)

    ## create date

        driver.find_element_by_id('filter-section-expand-createdDate').click()


    ## today

        driver.find_element_by_xpath('//*[@id="filter-options-createdDate"]/div[1]/div[2]/div/label/i').click()
        time.sleep(5)

    ## reclick filter
        driver.find_element_by_xpath('//*[@id="filter-dropdown-btn"]').click()

        time.sleep(5)
    ## select latest
  

        #driver.find_element_by_partial_link_text(str(df_output['STEP_SPN_Name'].values[i])+',').click()
    
        driver.find_element_by_xpath('//*[@id="lst-lead-container"]/div[1]/div[1]/a').click() 
    
    

        time.sleep(5)


    ## switch to window

        driver.switch_to.window(driver.window_handles[1])


    ## amazon comments

        driver.find_element_by_xpath('//*[@id="pc-amazonComments-edit"]').click()

        amazon_comments= driver.find_element_by_xpath('//*[@id="pc-amazonComments-input"]')

        amazon_comments.send_keys(str(df_output['amazon comments'].values[i]))

        driver.find_element_by_xpath('//*[@id="pc-amazonComments-button"]').click()
        time.sleep(2)



    ## request source

        driver.find_element_by_xpath('//*[@id="pc-requestSource-edit"]').click() ##arrow
        driver.find_element_by_xpath('//*[@id="a-autoid-47-announce"]').click() ## admin button
        driver.find_element_by_link_text('Referral').click() ## search for referall
        driver.find_element_by_xpath('//*[@id="pc-requestSource-button"]').click() ## done button






    ## request sub code

        driver.find_element_by_xpath('//*[@id="pc-requestSourceSubCode-edit"]').click()
        request_sub_source=driver.find_element_by_xpath('//*[@id="pc-requestSourceSubCode-input"]')
        request_sub_source.send_keys('STEP Program Q2-2022')
        driver.find_element_by_xpath('//*[@id="pc-requestSourceSubCode-button"]').click()


    ## save button

        save_button = WebDriverWait(driver, 10).until(
           EC.presence_of_element_located((By.XPATH, '//*[@id="save-detail-btn-announce"]'))).click()


        df=df.append(df_output.iloc[i,:])
    





        #pyautogui.hotkey('ctrl', 'w')
        #driver.switch_to.window(driver.window_handles[0]) ## switch back to previous tab
        driver.close()
        #driver.refresh() ## refresh
        #time.sleep(2)
        #driver.find_element_by_xpath('//*[@id="nav-search-text"]').clear()
    except:
          df_fail=df_fail.append(df_output.iloc[i,:]) 
          driver.close()
          pass
                 

# df_fail.to_excel(r'C:\Users\arvinmvn\Desktop\reupload test\uploadfail.xlsx',index=False) 


 
df.to_excel(r"\\DESKTOP-KJM0HRO\Shared_Folder\Automation\Step Allocation Audt" + "\\" + date + "\\" + "reuploadpass.xlsx",index=False)

df_fail.to_excel(r"\\DESKTOP-KJM0HRO\Shared_Folder\Automation\Step Allocation Audt" + "\\" + date + "\\" + "reuploadfail.xlsx",index=False) 

#df_fail.to_excel(r'C:\Users\arvinmvn\Desktop\reupload test\uploadfail'+str(a+1)+'.xlsx',index=False)
# Out:
# <ipython-input-7-0fde73a80106>:30: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=driver_path, options=options)
# <ipython-input-7-0fde73a80106>:144: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("Training").click()
# <ipython-input-7-0fde73a80106>:216: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("Unknown").click()
# <ipython-input-7-0fde73a80106>:223: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="sellerSellInCountry"]/span/span').click()
# <ipython-input-7-0fde73a80106>:226: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("India").click()
# ...

# %%
date='2022-04-18'
df.to_excel(r"\\DESKTOP-KJM0HRO\Shared_Folder\Automation\Step Allocation Audt" + "\\" + date + "\\" + "reuploadpass.xlsx",index=False)

df_fail.to_excel(r"\\DESKTOP-KJM0HRO\Shared_Folder\Automation\Step Allocation Audt" + "\\" + date + "\\" + "reuploadfail.xlsx",index=False)
